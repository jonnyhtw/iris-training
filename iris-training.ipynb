# %%
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
import iris
import iris.quickplot as qplt
import cartopy.crs as ccrs

# %%
cubes = iris.load('/Users/Jonny/bk042a.pc18500101.pp')

# %%
cubes[6]
# Out:
# <iris 'Cube' of air_temperature / (K) (time: 360; pressure: 6; latitude: 145; longitude: 192)>

# %%
import copy
temp = copy.deepcopy(cubes[6])

# %%
temp.coord('pressure').points
# Out:
# array([200., 300., 500., 700., 850., 925.], dtype=float32)

# %%
temp[0][-1]
# Out:
# <iris 'Cube' of air_temperature / (K) (latitude: 145; longitude: 192)>

# %%
fig = plt.figure(figsize=[10,10])
ax = plt.subplot(1,1,1,projection=ccrs.PlateCarree())

ax.coastlines()

qplt.pcolormesh(temp[0][0])

plt.show();
